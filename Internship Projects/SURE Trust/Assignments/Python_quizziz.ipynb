# %%
x="Hello"
y="World"
z=x+y
print(z)
# Out:
# HelloWorld

# %%
x=y=z="Orange"  #No error

# %%
x,y,z="Orange" #error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-1e09668183ca> in <cell line: 1>()
# ----> 1 x,y,z="Orange"
#
# ValueError: too many values to unpack (expected 3)

# %%
x,y,z="Orange","Banana","Cherry"  #no error

# %%
x=True
y=False
z=False
if not x or y:
  print(1)
elif not x or not y and not z:
  print(2)
elif not x or y or not y and x:
  print(3)
else:
  print(4)
# Out:
# 2

# %%
x=[1,2,3]
y=x
y.append(4)
print(x)
# Out:
# [1, 2, 3, 4]

# %%
x=(1,2,3)
print(type(x))
# Out:
# <class 'tuple'>

# %%
x={1:"one",2:"two"}
print(x[1])
# Out:
# one

# %%
x=True + False
print(x)
# Out:
# 1

# %%
x="123"
print(int(x)+1)
# Out:
# 124

# %%
x="Hello"
print(list(x))
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
x=123
print(bool(x))
# Out:
# True

# %%
x="123"
y="456"
print(int(x+y))
# Out:
# 123456

# %%
x=10
y=20
print(x==y)
# Out:
# False

# %%
x=True
y=False
print( x and y)
# Out:
# False

# %%
x=10
while x>5:
  x-=1
print(x)
# Out:
# 5

# %%
x=[1,2,3,4,5]
for i in x:
  if i ==3:
    break
  print(i,end=" ")
# Out:
# 1 2

# %%
x=[1,2,3,4,5]
for i in x:
  if i==3:
    continue
  print(i,end= " ")
# Out:
# 1 2 4 5

# %%
x=[1,2,3]
y=[i**2 for i in x]
print(y)
# Out:
# [1, 4, 9]

# %%
x=[i for i in range(10)]
y=[i for i in x if i%2==0]
print(y)
# Out:
# [0, 2, 4, 6, 8]

# %%
x="  Hello  "
print(x.strip())
# Out:
# Hello

# %%
x="Hello"
print(x[-1])
# Out:
# o

# %%
x={1:"one",2:"two",3:"three"}
print(len(x))
# Out:
# 3

# %%
x=[1,2,3]
y=x.pop()
print(y)
# Out:
# 3

# %%
x={1,2,3}
y=list(x)
print(y)
# Out:
# [1, 2, 3]

# %%
def greet(name):
  return "Hello, "+name
print(greet("World"))
# Out:
# Hello, World

# %%
def add(x,y=2):
  return x+y
print(add(1,3))
# Out:
# 4

# %%
def add(x,y=2):
  return x+y
print(add(1))
# Out:
# 3

# %%
x=lambda a: a+10
print(x(5))
# Out:
# 15

# %%
fun=lambda x : x*fun(x-1) if x>1 else 1
fun(4)
# Out:
# 24

# %%
anagram=lambda x,y:sorted(x)==sorted(y)
anagram(help,phel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-9b497cb6151f> in <cell line: 2>()
#       1 anagram=lambda x,y:sorted(x)==sorted(y)
# ----> 2 anagram(help,phel)
#
# NameError: name 'phel' is not defined

# %%
anagram=lambda x,y:sorted(x)==sorted(y)
anagram('help','phel')
# Out:
# True

# %%
class Test:
  def __init__(self):
    self.x=1
t1=Test()
t2=Test()
t1.x=2
print(t2.x)
# Out:
# 1

# %%
class Test:
  def __init__(self,x):
    self.__x=x
t=Test(10)
print(t.__x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-ad4218592c75> in <cell line: 5>()
#       3     self.__x=x
#       4 t=Test(10)
# ----> 5 print(t.__x)
#
# AttributeError: 'Test' object has no attribute '__x'

# %%
class Parent:
  def func(self):
    print("This parent function")
class Child(Parent):
  pass
c=Child()
c.func()
# Out:
# This parent function

# %%
class Parent:
  def func(self):
    print("This parent function")
class Child(Parent):
  def func(self):
    super().func()
    print("This is child function")
c=Child()
c.func()
# Out:
# This parent function
# This is child function

# %%
class Parent:
  def func(self):
    print("This parent function")
class Child(Parent):
  def func(self):
    print("This is child function")
c=Child()
c.func()
# Out:
# This is child function

# %%
try:
  x=1/0
except ZeroDivisionError:
  x=0
finally:
  x=1
print(x)
# Out:
# 1

# %%
try:
  x=1/0
except ValueError:
  x=0
print(x)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-43-7d5bddf5c9c7> in <cell line: 1>()
#       1 try:
# ----> 2   x=1/0
#       3 except ValueError:
#       4   x=0
#       5 print(x)
#
# ZeroDivisionError: division by zero

# %%
try:
  x=1/0
except ZeroDivisionError:
  x=0
print(x)
# Out:
# 0

# %%
x="Hello"
print(x[1:4])
# Out:
# ell
